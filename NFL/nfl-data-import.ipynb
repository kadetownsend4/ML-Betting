# %% [markdown]
# # NFL Data Import
# This data is being pulled using [NFL-DATA-PY](https://pypi.org/project/nfl-data-py/) API

# %% [markdown]
# ### Import data and analyze the characteristics of the dataset

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.5.3

# %%
import nfl_data_py as nfl

# import the weekly data for each player in the 2024 NFL season 
weekly_stats_2024 = nfl.import_weekly_data([2024])

# display the weekly data
display(weekly_stats_2024)

# create a csv file to store the data
weekly_stats_2024.to_csv("weekly_nfl_stats_season/weekly_stats_2024.csv", index=False)
# Out:
# Downcasting floats.
#        player_id player_name player_display_name position position_group  \
# 0     00-0023459   A.Rodgers       Aaron Rodgers       QB             QB
# 1     00-0023459   A.Rodgers       Aaron Rodgers       QB             QB
# 2     00-0023459   A.Rodgers       Aaron Rodgers       QB             QB
# 3     00-0023459   A.Rodgers       Aaron Rodgers       QB             QB
# 4     00-0023459   A.Rodgers       Aaron Rodgers       QB             QB
# ...          ...         ...                 ...      ...            ...
# 5592  00-0039921    T.Benson         Trey Benson       RB             RB
# 5593  00-0039921    T.Benson         Trey Benson       RB             RB
# 5594  00-0039921    T.Benson         Trey Benson       RB             RB
# 5595  00-0039921    T.Benson         Trey Benson       RB             RB
# 5596  00-0039921    T.Benson         Trey Benson       RB             RB
#
#                                            headshot_url recent_team  season  \
# 0     https://static.www.nfl.com/image/upload/f_auto...         NYJ    2024
# 1     https://static.www.nfl.com/image/upload/f_auto...         NYJ    2024
# 2     https://static.www.nfl.com/image/upload/f_auto...         NYJ    2024
# 3     https://static.www.nfl.com/image/upload/f_auto...         NYJ    2024
# 4     https://static.www.nfl.com/image/upload/f_auto...         NYJ    2024
# ...                                                 ...         ...     ...
# 5592  https://static.www.nfl.com/image/upload/f_auto...         ARI    2024
# 5593  https://static.www.nfl.com/image/upload/f_auto...         ARI    2024
# 5594  https://static.www.nfl.com/image/upload/f_auto...         ARI    2024
# 5595  https://static.www.nfl.com/image/upload/f_auto...         ARI    2024
# 5596  https://static.www.nfl.com/image/upload/f_auto...         ARI    2024
#
#       week season_type  ... receiving_first_downs  receiving_epa  \
# 0        1         REG  ...                   0.0            NaN
# 1        2         REG  ...                   0.0            NaN
# 2        3         REG  ...                   0.0            NaN
# 3        4         REG  ...                   0.0            NaN
# 4        5         REG  ...                   0.0            NaN
# ...    ...         ...  ...                   ...            ...
# 5592    10         REG  ...                   2.0       1.987017
# 5593    12         REG  ...                   0.0            NaN
# 5594    13         REG  ...                   0.0            NaN
# 5595    14         REG  ...                   0.0      -0.144496
# 5596    15         REG  ...                   0.0            NaN
#
#       receiving_2pt_conversions   racr  target_share  air_yards_share  \
# 0                             0    NaN           NaN              NaN
# 1                             0    NaN           NaN              NaN
# 2                             0    NaN           NaN              NaN
# 3                             0    NaN           NaN              NaN
# 4                             0    NaN           NaN              NaN
# ...                         ...    ...           ...              ...
# 5592                          0 -3.125      0.083333        -0.072072
# 5593                          0    NaN           NaN              NaN
# 5594                          0    NaN           NaN              NaN
# 5595                          0 -0.800      0.026316        -0.031847
# 5596                          0    NaN           NaN              NaN
#
#           wopr  special_teams_tds  fantasy_points  fantasy_points_ppr
# 0          NaN                0.0        8.580000            8.580000
# 1          NaN                0.0       15.140000           15.140000
# 2          NaN                0.0       21.040001           21.040001
# 3          NaN                0.0       11.600000           11.600000
# 4          NaN                0.0       11.760000           11.760000
# ...        ...                ...             ...                 ...
# 5592  0.074550                0.0        8.700000           10.700000
# 5593       NaN                0.0        1.800000            1.800000
# 5594       NaN                0.0        2.000000            2.000000
# 5595  0.017181                0.0        1.900000            2.900000
# 5596       NaN                0.0        2.200000            2.200000
#
# [5597 rows x 53 columns]

# %%
weekly_stats_2023 = nfl.import_weekly_data([2023])

display(weekly_stats_2023)

weekly_stats_2023.to_csv("weekly_nfl_stats_season/weekly_stats_2023.csv", index=False)
# Out:
# Downcasting floats.
#        player_id   player_name player_display_name position position_group  \
# 0     00-0023459     A.Rodgers       Aaron Rodgers       QB             QB
# 1     00-0024243       M.Lewis      Marcedes Lewis       TE             TE
# 2     00-0024243       M.Lewis      Marcedes Lewis       TE             TE
# 3     00-0024243       M.Lewis      Marcedes Lewis       TE             TE
# 4     00-0024243       M.Lewis      Marcedes Lewis       TE             TE
# ...          ...           ...                 ...      ...            ...
# 5648  00-0039165  Z.Charbonnet     Zach Charbonnet       RB             RB
# 5649  00-0039165  Z.Charbonnet     Zach Charbonnet       RB             RB
# 5650  00-0039165  Z.Charbonnet     Zach Charbonnet       RB             RB
# 5651  00-0039165  Z.Charbonnet     Zach Charbonnet       RB             RB
# 5652  00-0039165  Z.Charbonnet     Zach Charbonnet       RB             RB
#
#                                            headshot_url recent_team  season  \
# 0     https://static.www.nfl.com/image/upload/f_auto...         NYJ    2023
# 1     https://static.www.nfl.com/image/private/f_aut...         CHI    2023
# 2     https://static.www.nfl.com/image/private/f_aut...         CHI    2023
# 3     https://static.www.nfl.com/image/private/f_aut...         CHI    2023
# 4     https://static.www.nfl.com/image/private/f_aut...         CHI    2023
# ...                                                 ...         ...     ...
# 5648  https://static.www.nfl.com/image/upload/f_auto...         SEA    2023
# 5649  https://static.www.nfl.com/image/upload/f_auto...         SEA    2023
# 5650  https://static.www.nfl.com/image/upload/f_auto...         SEA    2023
# 5651  https://static.www.nfl.com/image/upload/f_auto...         SEA    2023
# 5652  https://static.www.nfl.com/image/upload/f_auto...         SEA    2023
#
#       week season_type  ... receiving_first_downs  receiving_epa  \
# 0        1         REG  ...                   0.0            NaN
# 1        4         REG  ...                   0.0       0.483465
# 2        7         REG  ...                   1.0       1.437224
# 3       11         REG  ...                   0.0      -0.547367
# 4       14         REG  ...                   0.0      -0.190257
# ...    ...         ...  ...                   ...            ...
# 5648    14         REG  ...                   0.0      -0.787724
# 5649    15         REG  ...                   0.0      -0.442067
# 5650    16         REG  ...                   0.0      -1.961893
# 5651    17         REG  ...                   2.0       1.644468
# 5652    18         REG  ...                   2.0       1.740490
#
#       receiving_2pt_conversions      racr  target_share  air_yards_share  \
# 0                             0       NaN           NaN              NaN
# 1                             0  0.000000      0.031250        -0.012397
# 2                             0  3.200000      0.034483         0.094340
# 3                             0  0.000000      0.045455         0.036885
# 4                             0  0.000000      0.033333        -0.012987
# ...                         ...       ...           ...              ...
# 5648                          0 -0.666667      0.032258        -0.025532
# 5649                          0  0.000000      0.031250         0.012658
# 5650                          0  0.307692      0.055556        -0.056034
# 5651                          0  3.000000      0.151515         0.057778
# 5652                          0  5.600000      0.076923         0.031447
#
#           wopr  special_teams_tds  fantasy_points  fantasy_points_ppr
# 0          NaN                0.0             0.0                 0.0
# 1     0.038197                0.0             0.8                 1.8
# 2     0.117762                0.0             1.6                 2.6
# 3     0.094001                0.0             0.0                 0.0
# 4     0.040909                0.0             0.4                 1.4
# ...        ...                ...             ...                 ...
# 5648  0.030515                0.0             4.8                 5.8
# 5649  0.055736                0.0             1.6                 1.6
# 5650  0.044109                0.0            -0.4                 0.6
# 5651  0.267717                0.0             4.1                 9.1
# 5652  0.137397                0.0             6.0                 8.0
#
# [5653 rows x 53 columns]

# %% [markdown]
# I asked ChatGPT for help with the process of organizing the weekly player data into dataframes to be used for our machine learning process. Here is the link to Chat: https://chatgpt.com/share/67a7d9ef-d054-800f-a70d-36bf42bdf994

# %%
# View the different columns in the dataframe to figure out what statistics are available for each player
print(weekly_stats_2024.columns)
# Out:
# Index(['player_id', 'player_name', 'player_display_name', 'position',
#        'position_group', 'headshot_url', 'recent_team', 'season', 'week',
#        'season_type', 'opponent_team', 'completions', 'attempts',
#        'passing_yards', 'passing_tds', 'interceptions', 'sacks', 'sack_yards',
#        'sack_fumbles', 'sack_fumbles_lost', 'passing_air_yards',
#        'passing_yards_after_catch', 'passing_first_downs', 'passing_epa',
#        'passing_2pt_conversions', 'pacr', 'dakota', 'carries', 'rushing_yards',
#        'rushing_tds', 'rushing_fumbles', 'rushing_fumbles_lost',
#        'rushing_first_downs', 'rushing_epa', 'rushing_2pt_conversions',
#        'receptions', 'targets', 'receiving_yards', 'receiving_tds',
#        'receiving_fumbles', 'receiving_fumbles_lost', 'receiving_air_yards',
#        'receiving_yards_after_catch', 'receiving_first_downs', 'receiving_epa',
#        'receiving_2pt_conversions', 'racr', 'target_share', 'air_yards_share',
#        'wopr', 'special_teams_tds', 'fantasy_points', 'fantasy_points_ppr'],
#       dtype='object')

# %%
# View all the different positions in the NFL
print(weekly_stats_2024['position'].unique())
# Out:
# ['QB' 'TE' 'P' 'FS' 'FB' 'WR' 'RB' 'CB' 'T' 'SS' 'OLB' 'DE' 'MLB' 'G'
#  'ILB']

# %% [markdown]
# ### Create New Dataframes For Offensive Positions
# Most player props offered for the NFL are typically for the offensive players. Some of these player props typically include:
# - Passing, Rushing, Recieving Yards
# - Passing, Rushing, Recieving Touchdowns
# - Pass Completions
# - Receptions
# - Fumbles and Interceptions
# - Fantasy Score
#
# Each position has different statistics which are most telling of how they will perform in a specfic game. We are seperating feature creation into seperate features for different positions to allow us to accurately capture how each position plays and gain a greater understanding of how different advanced statistics can be used to improve the accuracy of our predicitions.

# %% [markdown]
# #### Quarterbacks
# Some of the most important factors to consider when analyzing quarter back performance according to [this article](https://mfootballanalytics.com/2020/04/06/which-qb-stats-are-the-most-important/) are:
#  - Completion Percentage
#  - Yards per Attempt
#  - Touchdown Percentage
#  - Interception Percentage
#  - Passer Rating
#  - Adjusted Net Yards per Pass Attempt

# %%
# This code block was taken directly from the chat linked above. I decided on the filtered statistics to be used in the dataframe once it gave me 
# guidance on how to filter the dataframe. Then, I asked for help implementing the above statistics into the dataframe. It helped me implement 
# these statistics and suggested additional ones which were the rolling averages and rushing metrics. It provided the code for this as well. 
# Link to chat: https://chatgpt.com/share/67a7d9ef-d054-800f-a70d-36bf42bdf994
# (This is the same link provided above in the markdown comment, but I included it here as well to ensure that the referencing of AI usage is clear)

import numpy as np
import pandas as pd


# Create a filtered copy with relevant stats for passing & rushing
qb_df = weekly_stats_2024[weekly_stats_2024['position'] == 'QB'][['player_id', 'player_name', 'position', 'recent_team', 'week', 'season_type',
                           'opponent_team', 'completions', 'attempts', 'passing_yards',
                           'passing_tds', 'interceptions', 'sacks', 'sack_yards',
                           'carries', 'rushing_yards', 'rushing_tds']].copy()

# Sort by player and week (ensures rolling averages work correctly)
qb_df = qb_df.sort_values(by=['player_id', 'week'])

# Avoid division by zero
qb_df['attempts'] = qb_df['attempts'].replace(0, np.nan)
qb_df['carries'] = qb_df['carries'].replace(0, np.nan)

# Passing Metrics
qb_df['completion_pct'] = (qb_df['completions'] / qb_df['attempts']) * 100
qb_df['yards_per_attempt'] = qb_df['passing_yards'] / qb_df['attempts']
qb_df['td_pct'] = (qb_df['passing_tds'] / qb_df['attempts']) * 100
qb_df['int_pct'] = (qb_df['interceptions'] / qb_df['attempts']) * 100

# Passer Rating Formula
qb_df['a'] = ((qb_df['completions'] / qb_df['attempts']) - 0.3) * 5
qb_df['b'] = ((qb_df['passing_yards'] / qb_df['attempts']) - 3) * 0.25
qb_df['c'] = (qb_df['passing_tds'] / qb_df['attempts']) * 20
qb_df['d'] = 2.375 - ((qb_df['interceptions'] / qb_df['attempts']) * 25)

qb_df[['a', 'b', 'c', 'd']] = qb_df[['a', 'b', 'c', 'd']].clip(0, 2.375)
qb_df['passer_rating'] = ((qb_df['a'] + qb_df['b'] + qb_df['c'] + qb_df['d']) / 6) * 100

# Adjusted Net Yards per Attempt (ANY/A)
qb_df['adjusted_net_yards_per_attempt'] = (
    (qb_df['passing_yards'] - qb_df['sack_yards'] + (20 * qb_df['passing_tds']) - (45 * qb_df['interceptions'])) 
    / (qb_df['attempts'] + qb_df['sacks'])
)

# Drop temp calculation columns
qb_df.drop(columns=['a', 'b', 'c', 'd'], inplace=True)

# Rushing Metrics
qb_df['yards_per_carry'] = qb_df['rushing_yards'] / qb_df['carries']

# I originally implented rolling averages using the current week's game. I realized that this would not be possible when making predicitions for live data 
# so I asked ChatGPT how to ensure the rolling averages are shifted to the last game. I was running into some trouble with the wr, te, and rb dataframe calculations
# and it told me to use a lambda function to help with the calulcation which ended up fixing the issue. 
# Link to the chat: https://chatgpt.com/share/67b6483b-4ae0-800f-b017-46d385c257c8

# Rolling Averages (Last 3 Games, Last 5 Games, Season Avg)
rolling_windows = [3, 5]  # Last 3 games, last 5 games
rolling_cols = ['completion_pct', 'yards_per_attempt', 'td_pct', 'int_pct',
                'passer_rating', 'adjusted_net_yards_per_attempt', 'rushing_yards', 'yards_per_carry']

# Compute rolling averages for each player
for window in rolling_windows:
    for col in rolling_cols:
        qb_df[f'{col}_rolling_{window}'] = qb_df.groupby('player_id')[col].shift(1).rolling(window, min_periods=1).mean().reset_index(level=0, drop=True)

# Compute season-to-date averages
for col in rolling_cols:
    qb_df[f'{col}_season_avg'] = qb_df.groupby('player_id')[col].shift(1).expanding().mean().reset_index(level=0, drop=True)

# Save to CSV
qb_df.to_csv("player_position_dataframes/qb_advanced_stats_rolling_2024.csv", index=False)

# Display relevant columns
display(qb_df[['player_name', 'week', 'attempts', 'completions', 'completion_pct', 'yards_per_attempt', 'td_pct', 'passer_rating', 
             'adjusted_net_yards_per_attempt', 'rushing_yards', 'yards_per_carry', 
             'completion_pct_rolling_3', 'completion_pct_rolling_5', 'completion_pct_season_avg']].head())
# Out:
#   player_name  week  attempts  completions  completion_pct  yards_per_attempt  \
# 0   A.Rodgers     1      21.0           13       61.904762           7.952381
# 1   A.Rodgers     2      30.0           18       60.000000           5.866667
# 2   A.Rodgers     3      35.0           27       77.142857           8.028571
# 3   A.Rodgers     4      42.0           24       57.142857           5.357143
# 4   A.Rodgers     5      54.0           29       53.703704           4.518519
#
#      td_pct  passer_rating  adjusted_net_yards_per_attempt  rushing_yards  \
# 0  4.761905      82.837302                        6.227273           -1.0
# 1  6.666667      98.750000                        6.375000            1.0
# 2  5.714286     118.869048                        8.297297           18.0
# 3  0.000000      72.023810                        3.914894           26.0
# 4  3.703704      54.861111                        2.157895            0.0
#
#    yards_per_carry  completion_pct_rolling_3  completion_pct_rolling_5  \
# 0             -1.0                       NaN                       NaN
# 1              0.5                 61.904762                 61.904762
# 2              6.0                 60.952381                 60.952381
# 3              5.2                 66.349206                 66.349206
# 4              NaN                 64.761905                 64.047619
#
#    completion_pct_season_avg
# 0                        NaN
# 1                  61.904762
# 2                  60.952381
# 3                  66.349206
# 4                  64.047619

# %%
display(qb_df)
# Out:
#        player_id player_name position recent_team  week season_type  \
# 0     00-0023459   A.Rodgers       QB         NYJ     1         REG
# 1     00-0023459   A.Rodgers       QB         NYJ     2         REG
# 2     00-0023459   A.Rodgers       QB         NYJ     3         REG
# 3     00-0023459   A.Rodgers       QB         NYJ     4         REG
# 4     00-0023459   A.Rodgers       QB         NYJ     5         REG
# ...          ...         ...      ...         ...   ...         ...
# 5558  00-0039918  C.Williams       QB         CHI    14         REG
# 5559  00-0039918  C.Williams       QB         CHI    15         REG
# 5560  00-0039918  C.Williams       QB         CHI    16         REG
# 5561  00-0039918  C.Williams       QB         CHI    17         REG
# 5562  00-0039918  C.Williams       QB         CHI    18         REG
#
#      opponent_team  completions  attempts  passing_yards  ...  \
# 0               SF           13      21.0          167.0  ...
# 1              TEN           18      30.0          176.0  ...
# 2               NE           27      35.0          281.0  ...
# 3              DEN           24      42.0          225.0  ...
# 4              MIN           29      54.0          244.0  ...
# ...            ...          ...       ...            ...  ...
# 5558            SF           17      23.0          134.0  ...
# 5559           MIN           18      31.0          191.0  ...
# 5560           DET           26      40.0          334.0  ...
# 5561           SEA           16      28.0          122.0  ...
# 5562            GB           21      29.0          148.0  ...
#
#       rushing_yards_rolling_5  yards_per_carry_rolling_5  \
# 0                         NaN                        NaN
# 1                        -1.0                  -1.000000
# 2                         0.0                  -0.250000
# 3                         6.0                   1.833333
# 4                        11.0                   2.675000
# ...                       ...                        ...
# 5558                      NaN                        NaN
# 5559                      NaN                        NaN
# 5560                      NaN                        NaN
# 5561                      NaN                        NaN
# 5562                      NaN                        NaN
#
#       completion_pct_season_avg  yards_per_attempt_season_avg  \
# 0                           NaN                           NaN
# 1                     61.904762                      7.952381
# 2                     60.952381                      6.909524
# 3                     66.349206                      7.282540
# 4                     64.047619                      6.801190
# ...                         ...                           ...
# 5558                        NaN                           NaN
# 5559                        NaN                           NaN
# 5560                        NaN                           NaN
# 5561                        NaN                           NaN
# 5562                        NaN                           NaN
#
#       td_pct_season_avg  int_pct_season_avg  passer_rating_season_avg  \
# 0                   NaN                 NaN                       NaN
# 1              4.761905            4.761905                 82.837302
# 2              5.714286            2.380952                 90.793651
# 3              5.714286            1.587302                100.152116
# 4              4.285714            1.190476                 93.120040
# ...                 ...                 ...                       ...
# 5558                NaN                 NaN                       NaN
# 5559                NaN                 NaN                       NaN
# 5560                NaN                 NaN                       NaN
# 5561                NaN                 NaN                       NaN
# 5562                NaN                 NaN                       NaN
#
#       adjusted_net_yards_per_attempt_season_avg  rushing_yards_season_avg  \
# 0                                           NaN                       NaN
# 1                                      6.227273                      -1.0
# 2                                      6.301136                       0.0
# 3                                      6.966523                       6.0
# 4                                      6.203616                      11.0
# ...                                         ...                       ...
# 5558                                        NaN                       NaN
# 5559                                        NaN                       NaN
# 5560                                        NaN                       NaN
# 5561                                        NaN                       NaN
# 5562                                        NaN                       NaN
#
#       yards_per_carry_season_avg
# 0                            NaN
# 1                      -1.000000
# 2                      -0.250000
# 3                       1.833333
# 4                       2.675000
# ...                          ...
# 5558                         NaN
# 5559                         NaN
# 5560                         NaN
# 5561                         NaN
# 5562                         NaN
#
# [697 rows x 48 columns]

# %%
# Printing out all feature colunmns
print(qb_df.columns)
# Out:
# Index(['player_id', 'player_name', 'position', 'recent_team', 'week',
#        'season_type', 'opponent_team', 'completions', 'attempts',
#        'passing_yards', 'passing_tds', 'interceptions', 'sacks', 'sack_yards',
#        'carries', 'rushing_yards', 'rushing_tds', 'completion_pct',
#        'yards_per_attempt', 'td_pct', 'int_pct', 'passer_rating',
#        'adjusted_net_yards_per_attempt', 'yards_per_carry',
#        'completion_pct_rolling_3', 'yards_per_attempt_rolling_3',
#        'td_pct_rolling_3', 'int_pct_rolling_3', 'passer_rating_rolling_3',
#        'adjusted_net_yards_per_attempt_rolling_3', 'rushing_yards_rolling_3',
#        'yards_per_carry_rolling_3', 'completion_pct_rolling_5',
#        'yards_per_attempt_rolling_5', 'td_pct_rolling_5', 'int_pct_rolling_5',
#        'passer_rating_rolling_5', 'adjusted_net_yards_per_attempt_rolling_5',
#        'rushing_yards_rolling_5', 'yards_per_carry_rolling_5',
#        'completion_pct_season_avg', 'yards_per_attempt_season_avg',
#        'td_pct_season_avg', 'int_pct_season_avg', 'passer_rating_season_avg',
#        'adjusted_net_yards_per_attempt_season_avg', 'rushing_yards_season_avg',
#        'yards_per_carry_season_avg'],
#       dtype='object')

# %%
# Checking to see if the list contains only quarterbacks 
print(qb_df['player_name'].unique())
# Out:
# ['A.Rodgers' 'J.Flacco' 'J.Johnson' 'M.Stafford' 'A.Dalton' 'T.Taylor'
#  'R.Wilson' 'K.Cousins' 'G.Smith' 'T.Bridgewater' 'D.Carr' 'J.Garoppolo'
#  'J.Winston' 'T.Heinicke' 'M.Mariota' 'B.Allen' 'C.Wentz' 'D.Prescott'
#  'J.Goff' 'J.Brissett' 'N.Mullens' 'D.Watson' 'C.Rush' 'M.Trubisky'
#  'P.Mahomes' 'J.Dobbs' 'T.Boyle' 'M.White' 'K.Allen' 'M.Rudolph'
#  'L.Jackson' 'B.Mayfield' 'J.Allen' 'S.Darnold' 'J.Browning' 'K.Murray'
#  'J.Stidham' 'G.Minshew' 'D.Lock' 'D.Jones' 'T.Huntley' 'T.Tagovailoa'
#  'J.Love' 'J.Herbert' 'J.Hurts' 'J.Burrow' 'D.Mills' 'K.Trask' 'J.Fields'
#  'T.Lawrence' 'M.Jones' 'T.Lance' 'S.Howell' 'C.Oladokun' 'S.Thompson'
#  'B.Purdy' 'K.Pickett' 'B.Zappe' 'D.Ridder' 'M.Willis' 'T.McKee'
#  'T.Bagent' 'T.DeVito' 'H.Hooker' "A.O'Connell" 'C.Tune'
#  'D.Thompson-Robinson' 'J.Haener' 'B.Young' 'W.Levis' 'C.Stroud'
#  'A.Richardson' 'S.Rattler' 'J.Milton' 'B.Nix' 'D.Maye' 'J.Daniels'
#  'M.Penix' 'C.Williams']

# %% [markdown]
# **AI-Usage:** I also recieved help from ChatGPT with the receiver, tight-end, and running back dataframe and feature creation since they all followed a similar process as the creation of the qb dataframe and features. I performed research on what features are most important to take into account for a positions performance. Then, I told chat gpt what features should be taken into account in the dataframe and asked for help with implementing the additional statistics and features for each player. It helped me implement this process. I proceeded to save the data to a csv, and print out the additional statistics to ensure validity of calculations.
#
# **ChatCPT Conversation Link**: https://chatgpt.com/share/67a7d9ef-d054-800f-a70d-36bf42bdf994

# %% [markdown]
# #### Recievers
# Some of the most important factors to consider when analyzing a recievers performance according to [this article](https://www.sharpfootballanalysis.com/fantasy/wide-receiver-stats-that-matter-fantasy-football-2023/#:~:text=Touchdowns%20are%20less%20important%20for,share%20are%20the%20stickiest%20metrics) are:
#  - Receiving yards
#  - Receptions
#  - Targets
#  - Receiving Touchdowns
#  - Snaps

# %%
# Filter WRs and select relevant columns
wr_df = weekly_stats_2024[weekly_stats_2024['position'] == 'WR'][[
    'player_id', 'player_name', 'position', 'recent_team', 'week', 'season_type',
    'opponent_team', 'receptions', 'targets', 'receiving_yards', 'receiving_tds',
    'receiving_fumbles', 'receiving_fumbles_lost', 'receiving_air_yards',
    'receiving_yards_after_catch', 'receiving_first_downs', 'receiving_epa',
    'receiving_2pt_conversions', 'racr', 'target_share', 'air_yards_share',
    'wopr', 'fantasy_points', 'fantasy_points_ppr'
]].copy()

# Sort by player and week for rolling averages
wr_df = wr_df.sort_values(by=['player_id', 'week'])

# Efficiency Metrics**
wr_df['catch_pct'] = (wr_df['receptions'] / wr_df['targets']) * 100  # Catch percentage
wr_df['yards_per_catch'] = wr_df['receiving_yards'] / wr_df['receptions']  # Yards per reception
wr_df['yards_per_target'] = wr_df['receiving_yards'] / wr_df['targets']  # Yards per target
wr_df['air_yards_per_target'] = wr_df['receiving_air_yards'] / wr_df['targets']  # Air yards per target
wr_df['yac_per_reception'] = wr_df['receiving_yards_after_catch'] / wr_df['receptions']  # Yards after catch per reception
wr_df['td_per_target'] = wr_df['receiving_tds'] / wr_df['targets']  # TD conversion rate
wr_df['first_down_per_target'] = wr_df['receiving_first_downs'] / wr_df['targets']  # First downs per target

# Rolling Averages (Last 3, 5 Games & Season-to-Date)
rolling_windows = [3, 5]  
rolling_cols = ['targets', 'receptions', 'receiving_yards', 'receiving_tds', 'catch_pct', 'yards_per_target', 
                'air_yards_per_target', 'yac_per_reception', 'td_per_target', 
                'first_down_per_target']

# Compute rolling averages using only past games
rolling_windows = [3, 5]
for window in rolling_windows:
    for col in rolling_cols:
        wr_df[f'{col}_rolling_{window}'] = (
            wr_df.groupby('player_id', group_keys=False)[col]
            .apply(lambda x: x.shift(1).rolling(window, min_periods=1).mean())
        )

# Compute season averages for the season only using past games
for col in rolling_cols:
    wr_df[f'{col}_season_avg'] = (
        wr_df.groupby('player_id', group_keys=False)[col]
        .apply(lambda x: x.shift(1).expanding().mean())
    )

# Save to CSV
wr_df.to_csv("player_position_dataframes/wr_advanced_stats_rolling_2024.csv", index=False)

# Display relevant columns
display(wr_df[['player_name', 'week', 'receptions', 'targets', 'receiving_yards', 'receiving_tds', 'catch_pct', 
               'receiving_yards_after_catch', 'receiving_first_downs', 'receiving_epa',
             'yards_per_target', 'air_yards_per_target', 'yac_per_reception',
             'targets_rolling_3', 'targets_rolling_5', 'targets_season_avg']].head(10))
# Out:
#     player_name  week  receptions  targets  receiving_yards  receiving_tds  \
# 100   A.Thielen     1           3        4             49.0              0
# 101   A.Thielen     2           2        3             20.0              0
# 102   A.Thielen     3           3        5             40.0              1
# 103   A.Thielen    12           3        4             57.0              0
# 104   A.Thielen    13           8       10             99.0              1
# 105   A.Thielen    14           9       11            102.0              0
# 106   A.Thielen    15           5        7             51.0              0
# 107   A.Thielen    16           5        6             43.0              1
# 108   A.Thielen    17           5        6            110.0              2
# 109   A.Thielen    18           5        6             44.0              0
#
#      catch_pct  receiving_yards_after_catch  receiving_first_downs  \
# 100  75.000000                         18.0                    2.0
# 101  66.666667                          2.0                    1.0
# 102  60.000000                          5.0                    2.0
# 103  75.000000                         35.0                    2.0
# 104  80.000000                         23.0                    4.0
# 105  81.818182                         13.0                    7.0
# 106  71.428571                         26.0                    1.0
# 107  83.333333                          7.0                    4.0
# 108  83.333333                         12.0                    4.0
# 109  83.333333                         11.0                    1.0
#
#      receiving_epa  yards_per_target  air_yards_per_target  yac_per_reception  \
# 100       4.642717         12.250000             16.000000           6.000000
# 101      -2.458903          6.666667              6.000000           1.000000
# 102       3.056416          8.000000              8.800000           1.666667
# 103       4.730047         14.250000              8.500000          11.666667
# 104       6.234365          9.900000             11.200000           2.875000
# 105       8.989361          9.272727             11.818182           1.444444
# 106      -2.725873          7.285714              8.857143           5.200000
# 107       6.882568          7.166667             10.333333           1.400000
# 108       9.249335         18.333333             18.833333           2.400000
# 109       1.829049          7.333333              8.833333           2.200000
#
#      targets_rolling_3  targets_rolling_5  targets_season_avg
# 100                NaN                NaN                 NaN
# 101           4.000000                4.0            4.000000
# 102           3.500000                3.5            3.500000
# 103           4.000000                4.0            4.000000
# 104           4.000000                4.0            4.000000
# 105           6.333333                5.2            5.200000
# 106           8.333333                6.6            6.166667
# 107           9.333333                7.4            6.285714
# 108           8.000000                7.6            6.250000
# 109           6.333333                8.0            6.222222

# %%
# Printing out all feature colunmns
print(wr_df.columns)
# Out:
# Index(['player_id', 'player_name', 'position', 'recent_team', 'week',
#        'season_type', 'opponent_team', 'receptions', 'targets',
#        'receiving_yards', 'receiving_tds', 'receiving_fumbles',
#        'receiving_fumbles_lost', 'receiving_air_yards',
#        'receiving_yards_after_catch', 'receiving_first_downs', 'receiving_epa',
#        'receiving_2pt_conversions', 'racr', 'target_share', 'air_yards_share',
#        'wopr', 'fantasy_points', 'fantasy_points_ppr', 'catch_pct',
#        'yards_per_catch', 'yards_per_target', 'air_yards_per_target',
#        'yac_per_reception', 'td_per_target', 'first_down_per_target',
#        'targets_rolling_3', 'receptions_rolling_3',
#        'receiving_yards_rolling_3', 'receiving_tds_rolling_3',
#        'catch_pct_rolling_3', 'yards_per_target_rolling_3',
#        'air_yards_per_target_rolling_3', 'yac_per_reception_rolling_3',
#        'td_per_target_rolling_3', 'first_down_per_target_rolling_3',
#        'targets_rolling_5', 'receptions_rolling_5',
#        'receiving_yards_rolling_5', 'receiving_tds_rolling_5',
#        'catch_pct_rolling_5', 'yards_per_target_rolling_5',
#        'air_yards_per_target_rolling_5', 'yac_per_reception_rolling_5',
#        'td_per_target_rolling_5', 'first_down_per_target_rolling_5',
#        'targets_season_avg', 'receptions_season_avg',
#        'receiving_yards_season_avg', 'receiving_tds_season_avg',
#        'catch_pct_season_avg', 'yards_per_target_season_avg',
#        'air_yards_per_target_season_avg', 'yac_per_reception_season_avg',
#        'td_per_target_season_avg', 'first_down_per_target_season_avg'],
#       dtype='object')

# %% [markdown]
# #### Tight Ends
# Some of the most important factors to consider when analyzing quarter back performance according to [this article](https://www.sharpfootballanalysis.com/fantasy/te-stats-that-matter-fantasy-football/):
# - Receiving yards
# - Receptions
# - Targets
# - Receiving Touchdowns
# - Snaps

# %%
# Filter TEs and select relevant columns
te_df = weekly_stats_2024[weekly_stats_2024['position'] == 'TE'][[
    'player_id', 'player_name', 'position', 'recent_team', 'week', 'season_type',
    'opponent_team', 'receptions', 'targets', 'receiving_yards', 'receiving_tds',
    'receiving_fumbles', 'receiving_fumbles_lost', 'receiving_air_yards',
    'receiving_yards_after_catch', 'receiving_first_downs', 'receiving_epa',
    'receiving_2pt_conversions', 'racr', 'target_share', 'air_yards_share',
    'wopr', 'fantasy_points', 'fantasy_points_ppr'
]].copy()

# Sort by player and week for rolling averages
te_df = te_df.sort_values(by=['player_id', 'week'])

# Per-Game Metrics
te_df['targets_per_game'] = te_df['targets']
te_df['receptions_per_game'] = te_df['receptions']
te_df['receiving_yards_per_game'] = te_df['receiving_yards']
te_df['receiving_tds_per_game'] = te_df['receiving_tds']

# Efficiency Metrics
te_df['catch_pct'] = (te_df['receptions'] / te_df['targets']) * 100  # Catch percentage
te_df['yards_per_catch'] = te_df['receiving_yards'] / te_df['receptions']  # Yards per reception
te_df['yards_per_target'] = te_df['receiving_yards'] / te_df['targets']  # Yards per target
te_df['air_yards_per_target'] = te_df['receiving_air_yards'] / te_df['targets']  # Air yards per target
te_df['yac_per_reception'] = te_df['receiving_yards_after_catch'] / te_df['receptions']  # Yards after catch per reception
te_df['td_per_target'] = te_df['receiving_tds'] / te_df['targets']  # TD conversion rate
te_df['first_down_per_target'] = te_df['receiving_first_downs'] / te_df['targets']  # First downs per target
te_df['routes_per_snap'] = te_df['racr']  # Proxy for Route/Snap %

# Rolling Averages (Last 3, 5 Games & Season-to-Date)
rolling_windows = [3, 5]  
rolling_cols = ['targets_per_game', 'receptions_per_game', 'receiving_yards_per_game', 
                'receiving_tds_per_game', 'catch_pct', 'yards_per_target', 
                'air_yards_per_target', 'yac_per_reception', 'td_per_target', 
                'first_down_per_target']
# Compute rolling averages using only past games
rolling_windows = [3, 5]
for window in rolling_windows:
    for col in rolling_cols:
        te_df[f'{col}_rolling_{window}'] = (
            te_df.groupby('player_id', group_keys=False)[col]
            .apply(lambda x: x.shift(1).rolling(window, min_periods=1).mean())
        )

# Compute season averages for the season only using past games
for col in rolling_cols:
    te_df[f'{col}_season_avg'] = (
        te_df.groupby('player_id', group_keys=False)[col]
        .apply(lambda x: x.shift(1).expanding().mean())
    )

# Save to CSV
te_df.to_csv("player_position_dataframes/te_advanced_stats_rolling_2024.csv", index=False)

# Display relevant columns
display(te_df[['player_name', 'week', 'targets_per_game', 'receptions_per_game', 
               'receiving_yards_per_game', 'receiving_tds_per_game', 'catch_pct', 
               'yards_per_target', 'air_yards_per_target', 'yac_per_reception',
            'targets_per_game_rolling_3', 'targets_per_game_rolling_5', 'targets_per_game_season_avg']].head())
# Out:
#     player_name  week  targets_per_game  receptions_per_game  \
# 17      M.Lewis     6                 1                    1
# 110      Z.Ertz     1                 4                    3
# 111      Z.Ertz     2                 4                    4
# 112      Z.Ertz     3                 5                    5
# 113      Z.Ertz     4                 3                    3
#
#      receiving_yards_per_game  receiving_tds_per_game  catch_pct  \
# 17                        2.0                       0      100.0
# 110                      28.0                       0       75.0
# 111                      62.0                       0      100.0
# 112                      38.0                       0      100.0
# 113                      22.0                       0      100.0
#
#      yards_per_target  air_yards_per_target  yac_per_reception  \
# 17           2.000000                  1.00           1.000000
# 110          7.000000                  7.00           2.333333
# 111         15.500000                 12.75           2.750000
# 112          7.600000                  6.60           1.000000
# 113          7.333333                  5.00           2.333333
#
#      targets_per_game_rolling_3  targets_per_game_rolling_5  \
# 17                          NaN                         NaN
# 110                         NaN                         NaN
# 111                    4.000000                    4.000000
# 112                    4.000000                    4.000000
# 113                    4.333333                    4.333333
#
#      targets_per_game_season_avg
# 17                           NaN
# 110                          NaN
# 111                     4.000000
# 112                     4.000000
# 113                     4.333333

# %%
display(te_df)
# Out:
#        player_id player_name position recent_team  week season_type  \
# 17    00-0024243     M.Lewis       TE         CHI     6         REG
# 110   00-0030061      Z.Ertz       TE         WAS     1         REG
# 111   00-0030061      Z.Ertz       TE         WAS     2         REG
# 112   00-0030061      Z.Ertz       TE         WAS     3         REG
# 113   00-0030061      Z.Ertz       TE         WAS     4         REG
# ...          ...         ...      ...         ...   ...         ...
# 5509  00-0039912   B.Sinnott       TE         WAS     7         REG
# 5510  00-0039912   B.Sinnott       TE         WAS     9         REG
# 5511  00-0039912   B.Sinnott       TE         WAS    13         REG
# 5512  00-0039912   B.Sinnott       TE         WAS    15         REG
# 5513  00-0039912   B.Sinnott       TE         WAS    21        POST
#
#      opponent_team  receptions  targets  receiving_yards  ...  \
# 17             JAX         1.0      1.0              2.0  ...
# 110             TB         3.0      4.0             28.0  ...
# 111            NYG         4.0      4.0             62.0  ...
# 112            CIN         5.0      5.0             38.0  ...
# 113            ARI         3.0      3.0             22.0  ...
# ...            ...         ...      ...              ...  ...
# 5509           CAR         2.0      2.0              6.0  ...
# 5510           NYG         1.0      1.0             12.0  ...
# 5511           TEN         1.0      1.0              3.0  ...
# 5512            NO         1.0      1.0              7.0  ...
# 5513           PHI         1.0      1.0             23.0  ...
#
#       targets_per_game_season_avg  receptions_per_game_season_avg  \
# 17                       5.375000                        3.812500
# 110                      4.581633                        3.611111
# 111                      4.575758                        3.615385
# 112                      4.540000                        3.615385
# 113                      4.504950                        3.615385
# ...                           ...                             ...
# 5509                          NaN                             NaN
# 5510                          NaN                             NaN
# 5511                          NaN                             NaN
# 5512                          NaN                             NaN
# 5513                          NaN                             NaN
#
#       receiving_yards_per_game_season_avg  receiving_tds_per_game_season_avg  \
# 17                              38.125000                           1.200000
# 110                             34.877778                           1.043478
# 111                             34.945055                           1.043478
# 112                             34.945055                           1.043478
# 113                             34.945055                           1.043478
# ...                                   ...                                ...
# 5509                                  NaN                                NaN
# 5510                                  NaN                                NaN
# 5511                                  NaN                                NaN
# 5512                                  NaN                                NaN
# 5513                                  NaN                                NaN
#
#       catch_pct_season_avg  yards_per_target_season_avg  \
# 17               76.254058                     7.640104
# 110              76.988222                     7.137430
# 111              77.241098                     7.171634
# 112              77.241098                     7.171634
# 113              77.241098                     7.171634
# ...                    ...                          ...
# 5509                   NaN                          NaN
# 5510                   NaN                          NaN
# 5511                   NaN                          NaN
# 5512                   NaN                          NaN
# 5513                   NaN                          NaN
#
#       air_yards_per_target_season_avg  yac_per_reception_season_avg  \
# 17                           7.354471                      2.802083
# 110                          5.917486                      4.366206
# 111                          5.926069                      4.356363
# 112                          5.886007                      4.356363
# 113                          6.038673                      4.356363
# ...                               ...                           ...
# 5509                              NaN                           NaN
# 5510                              NaN                           NaN
# 5511                              NaN                           NaN
# 5512                              NaN                           NaN
# 5513                              NaN                           NaN
#
#       td_per_target_season_avg  first_down_per_target_season_avg
# 17                    0.184048                          0.497910
# 110                   0.300899                          0.471246
# 111                   0.300899                          0.468173
# 112                   0.300899                          0.468173
# 113                   0.300899                          0.468173
# ...                        ...                               ...
# 5509                       NaN                               NaN
# 5510                       NaN                               NaN
# 5511                       NaN                               NaN
# 5512                       NaN                               NaN
# 5513                       NaN                               NaN
#
# [1137 rows x 66 columns]

# %%
# Printing out all feature colunmns
print(te_df.columns)
# Out:
# Index(['player_id', 'player_name', 'position', 'recent_team', 'week',
#        'season_type', 'opponent_team', 'receptions', 'targets',
#        'receiving_yards', 'receiving_tds', 'receiving_fumbles',
#        'receiving_fumbles_lost', 'receiving_air_yards',
#        'receiving_yards_after_catch', 'receiving_first_downs', 'receiving_epa',
#        'receiving_2pt_conversions', 'racr', 'target_share', 'air_yards_share',
#        'wopr', 'fantasy_points', 'fantasy_points_ppr', 'targets_per_game',
#        'receptions_per_game', 'receiving_yards_per_game',
#        'receiving_tds_per_game', 'catch_pct', 'yards_per_catch',
#        'yards_per_target', 'air_yards_per_target', 'yac_per_reception',
#        'td_per_target', 'first_down_per_target', 'routes_per_snap',
#        'targets_per_game_rolling_3', 'receptions_per_game_rolling_3',
#        'receiving_yards_per_game_rolling_3',
#        'receiving_tds_per_game_rolling_3', 'catch_pct_rolling_3',
#        'yards_per_target_rolling_3', 'air_yards_per_target_rolling_3',
#        'yac_per_reception_rolling_3', 'td_per_target_rolling_3',
#        'first_down_per_target_rolling_3', 'targets_per_game_rolling_5',
#        'receptions_per_game_rolling_5', 'receiving_yards_per_game_rolling_5',
#        'receiving_tds_per_game_rolling_5', 'catch_pct_rolling_5',
#        'yards_per_target_rolling_5', 'air_yards_per_target_rolling_5',
#        'yac_per_reception_rolling_5', 'td_per_target_rolling_5',
#        'first_down_per_target_rolling_5', 'targets_per_game_season_avg',
#        'receptions_per_game_season_avg', 'receiving_yards_per_game_season_avg',
#        'receiving_tds_per_game_season_avg', 'catch_pct_season_avg',
#        'yards_per_target_season_avg', 'air_yards_per_target_season_avg',
#        'yac_per_reception_season_avg', 'td_per_target_season_avg',
#        'first_down_per_target_season_avg'],
#       dtype='object')

# %% [markdown]
# #### Running Backs
# Some of the most important factors to consider when analyzing quarter back performance according to [this article](https://www.sharpfootballanalysis.com/fantasy/running-back-stats-that-matter-fantasy-football-2023/):
#  - Touches
#  - Total Touchdowns
#  - Rushing Attempts
#  - Rushing Yards
#  - Receptions
#  - Rushing TDs
#  - Receiving yards
#  - Snaps
#  - Targets
#  - Receiving TDs

# %%
# Filter RBs and select relevant columns
rb_df = weekly_stats_2024[weekly_stats_2024['position'] == 'RB'][[
    'player_id', 'player_name', 'position', 'recent_team', 'week', 'season_type',
    'opponent_team', 'carries', 'rushing_yards', 'rushing_tds',
    'rushing_fumbles', 'rushing_fumbles_lost', 'rushing_first_downs', 'rushing_epa',
    'rushing_2pt_conversions', 'receiving_yards', 'receptions', 'targets',
    'receiving_tds', 'fantasy_points', 'fantasy_points_ppr'
]].copy()

# Sort by player and week for rolling averages
rb_df = rb_df.sort_values(by=['player_id', 'week'])


# Per-Game Metrics
rb_df['carries_per_game'] = rb_df['carries']
rb_df['rush_yards_per_game'] = rb_df['rushing_yards']
rb_df['rush_tds_per_game'] = rb_df['rushing_tds']
rb_df['targets_per_game'] = rb_df['targets']
rb_df['receptions_per_game'] = rb_df['receptions']
rb_df['receiving_yards_per_game'] = rb_df['receiving_yards']
rb_df['total_yards_per_game'] = rb_df['rushing_yards'] + rb_df['receiving_yards']  # YFS (Yards from Scrimmage)
rb_df['touches_per_game'] = rb_df['carries'] + rb_df['receptions']  # Total touches

# Efficiency Metrics
rb_df['yards_per_carry'] = rb_df['rushing_yards'] / rb_df['carries']  # Rushing efficiency
rb_df['yards_per_touch'] = (rb_df['rushing_yards'] + rb_df['receiving_yards']) / rb_df['touches_per_game']  # Yards per total touch
rb_df['yards_per_catch'] = rb_df['receiving_yards'] / rb_df['receptions']  # Receiving yards per catch
rb_df['yards_per_target'] = rb_df['receiving_yards'] / rb_df['targets']  # Receiving efficiency per target
rb_df['td_per_touch'] = (rb_df['rushing_tds'] + rb_df['receiving_tds']) / rb_df['touches_per_game']  # TD efficiency

# Rolling Averages (Last 3, 5 Games & Season-to-Date)
rolling_windows = [3, 5]
rolling_cols = ['carries_per_game', 'rush_yards_per_game', 'rush_tds_per_game',
                'targets_per_game', 'receptions_per_game', 'receiving_yards_per_game',
                'total_yards_per_game', 'touches_per_game', 'yards_per_carry',
                'yards_per_touch', 'yards_per_catch', 'yards_per_target', 'td_per_touch']

# Compute rolling averages using only past games
rolling_windows = [3, 5]
for window in rolling_windows:
    for col in rolling_cols:
        rb_df[f'{col}_rolling_{window}'] = (
            rb_df.groupby('player_id', group_keys=False)[col]
            .apply(lambda x: x.shift(1).rolling(window, min_periods=1).mean())
        )

# Compute season averages for the season only using past games
for col in rolling_cols:
    rb_df[f'{col}_season_avg'] = (
        rb_df.groupby('player_id', group_keys=False)[col]
        .apply(lambda x: x.shift(1).expanding().mean())
    )

# Save to CSV
rb_df.to_csv("player_position_dataframes/rb_advanced_stats_rolling_2024.csv", index=False)

# Display relevant columns
display(rb_df[['player_id', 'player_name', 'week', 'carries_per_game', 'rush_yards_per_game', 
             'rush_tds_per_game', 'targets_per_game', 'receptions_per_game', 
             'receiving_yards_per_game', 'total_yards_per_game', 'touches_per_game', 
             'yards_per_carry', 'yards_per_touch', 'td_per_touch',
             'carries_per_game_rolling_3', 'carries_per_game_rolling_5', 
             'carries_per_game_season_avg']].head())
# Out:
#       player_id  player_name  week  carries_per_game  rush_yards_per_game  \
# 214  00-0030578  C.Patterson     1                 4                 13.0
# 215  00-0030578  C.Patterson     2                 2                  3.0
# 216  00-0030578  C.Patterson     3                 4                 33.0
# 217  00-0030578  C.Patterson     4                 6                 43.0
# 218  00-0030578  C.Patterson    10                 3                 14.0
#
#      rush_tds_per_game  targets_per_game  receptions_per_game  \
# 214                  0                 0                    0
# 215                  0                 0                    0
# 216                  0                 5                    3
# 217                  0                 2                    2
# 218                  0                 0                    0
#
#      receiving_yards_per_game  total_yards_per_game  touches_per_game  \
# 214                       0.0                  13.0                 4
# 215                       0.0                   3.0                 2
# 216                      15.0                  48.0                 7
# 217                      19.0                  62.0                 8
# 218                       0.0                  14.0                 3
#
#      yards_per_carry  yards_per_touch  td_per_touch  \
# 214         3.250000         3.250000           0.0
# 215         1.500000         1.500000           0.0
# 216         8.250000         6.857143           0.0
# 217         7.166667         7.750000           0.0
# 218         4.666667         4.666667           0.0
#
#      carries_per_game_rolling_3  carries_per_game_rolling_5  \
# 214                         NaN                         NaN
# 215                    4.000000                    4.000000
# 216                    3.000000                    3.000000
# 217                    3.333333                    3.333333
# 218                    4.000000                    4.000000
#
#      carries_per_game_season_avg
# 214                          NaN
# 215                     4.000000
# 216                     3.000000
# 217                     3.333333
# 218                     4.000000

# %%
display(rb_df)
# Out:
#        player_id  player_name position recent_team  week season_type  \
# 214   00-0030578  C.Patterson       RB         PIT     1         REG
# 215   00-0030578  C.Patterson       RB         PIT     2         REG
# 216   00-0030578  C.Patterson       RB         PIT     3         REG
# 217   00-0030578  C.Patterson       RB         PIT     4         REG
# 218   00-0030578  C.Patterson       RB         PIT    10         REG
# ...          ...          ...      ...         ...   ...         ...
# 5592  00-0039921     T.Benson       RB         ARI    10         REG
# 5593  00-0039921     T.Benson       RB         ARI    12         REG
# 5594  00-0039921     T.Benson       RB         ARI    13         REG
# 5595  00-0039921     T.Benson       RB         ARI    14         REG
# 5596  00-0039921     T.Benson       RB         ARI    15         REG
#
#      opponent_team  carries  rushing_yards  rushing_tds  ...  \
# 214            ATL      4.0           13.0          NaN  ...
# 215            DEN      2.0            3.0          NaN  ...
# 216            LAC      4.0           33.0          NaN  ...
# 217            IND      6.0           43.0          NaN  ...
# 218            WAS      3.0           14.0          NaN  ...
# ...            ...      ...            ...          ...  ...
# 5592           NYJ     10.0           62.0          NaN  ...
# 5593           SEA      4.0           18.0          NaN  ...
# 5594           MIN      3.0           20.0          NaN  ...
# 5595           SEA      2.0           15.0          NaN  ...
# 5596            NE      5.0           22.0          NaN  ...
#
#       targets_per_game_season_avg  receptions_per_game_season_avg  \
# 214                      3.092486                        2.566265
# 215                      3.086207                        2.562874
# 216                      3.086207                        2.562874
# 217                      3.086207                        2.562874
# 218                      3.086207                        2.562874
# ...                           ...                             ...
# 5592                          NaN                             NaN
# 5593                          NaN                             NaN
# 5594                          NaN                             NaN
# 5595                          NaN                             NaN
# 5596                          NaN                             NaN
#
#       receiving_yards_per_game_season_avg  total_yards_per_game_season_avg  \
# 214                             22.359756                        75.617450
# 215                             22.321212                        75.426667
# 216                             22.321212                        75.426667
# 217                             22.321212                        75.426667
# 218                             22.321212                        75.426667
# ...                                   ...                              ...
# 5592                                  NaN                              NaN
# 5593                                  NaN                              NaN
# 5594                                  NaN                              NaN
# 5595                                  NaN                              NaN
# 5596                                  NaN                              NaN
#
#       touches_per_game_season_avg  yards_per_carry_season_avg  \
# 214                     14.437086                    4.365168
# 215                     14.421053                    4.358217
# 216                     14.421053                    4.348062
# 217                     14.421053                    4.352693
# 218                     14.421053                    4.331867
# ...                           ...                         ...
# 5592                          NaN                         NaN
# 5593                          NaN                         NaN
# 5594                          NaN                         NaN
# 5595                          NaN                         NaN
# 5596                          NaN                         NaN
#
#       yards_per_touch_season_avg  yards_per_catch_season_avg  \
# 214                     5.283828                    9.073047
# 215                     5.274714                    9.066544
# 216                     5.274714                    9.066544
# 217                     5.274714                    9.066544
# 218                     5.274714                    9.066544
# ...                          ...                         ...
# 5592                         NaN                         NaN
# 5593                         NaN                         NaN
# 5594                         NaN                         NaN
# 5595                         NaN                         NaN
# 5596                         NaN                         NaN
#
#       yards_per_target_season_avg  td_per_touch_season_avg
# 214                      7.708629                 0.129742
# 215                      7.710394                 0.129742
# 216                      7.710394                 0.129742
# 217                      7.710394                 0.129742
# 218                      7.710394                 0.129742
# ...                           ...                      ...
# 5592                          NaN                      NaN
# 5593                          NaN                      NaN
# 5594                          NaN                      NaN
# 5595                          NaN                      NaN
# 5596                          NaN                      NaN
#
# [1408 rows x 73 columns]

# %%
print(rb_df.columns)
# Out:
# Index(['player_id', 'player_name', 'position', 'recent_team', 'week',
#        'season_type', 'opponent_team', 'carries', 'rushing_yards',
#        'rushing_tds', 'rushing_fumbles', 'rushing_fumbles_lost',
#        'rushing_first_downs', 'rushing_epa', 'rushing_2pt_conversions',
#        'receiving_yards', 'receptions', 'targets', 'receiving_tds',
#        'fantasy_points', 'fantasy_points_ppr', 'carries_per_game',
#        'rush_yards_per_game', 'rush_tds_per_game', 'targets_per_game',
#        'receptions_per_game', 'receiving_yards_per_game',
#        'total_yards_per_game', 'touches_per_game', 'yards_per_carry',
#        'yards_per_touch', 'yards_per_catch', 'yards_per_target',
#        'td_per_touch', 'carries_per_game_rolling_3',
#        'rush_yards_per_game_rolling_3', 'rush_tds_per_game_rolling_3',
#        'targets_per_game_rolling_3', 'receptions_per_game_rolling_3',
#        'receiving_yards_per_game_rolling_3', 'total_yards_per_game_rolling_3',
#        'touches_per_game_rolling_3', 'yards_per_carry_rolling_3',
#        'yards_per_touch_rolling_3', 'yards_per_catch_rolling_3',
#        'yards_per_target_rolling_3', 'td_per_touch_rolling_3',
#        'carries_per_game_rolling_5', 'rush_yards_per_game_rolling_5',
#        'rush_tds_per_game_rolling_5', 'targets_per_game_rolling_5',
#        'receptions_per_game_rolling_5', 'receiving_yards_per_game_rolling_5',
#        'total_yards_per_game_rolling_5', 'touches_per_game_rolling_5',
#        'yards_per_carry_rolling_5', 'yards_per_touch_rolling_5',
#        'yards_per_catch_rolling_5', 'yards_per_target_rolling_5',
#        'td_per_touch_rolling_5', 'carries_per_game_season_avg',
#        'rush_yards_per_game_season_avg', 'rush_tds_per_game_season_avg',
#        'targets_per_game_season_avg', 'receptions_per_game_season_avg',
#        'receiving_yards_per_game_season_avg',
#        'total_yards_per_game_season_avg', 'touches_per_game_season_avg',
#        'yards_per_carry_season_avg', 'yards_per_touch_season_avg',
#        'yards_per_catch_season_avg', 'yards_per_target_season_avg',
#        'td_per_touch_season_avg'],
#       dtype='object')
